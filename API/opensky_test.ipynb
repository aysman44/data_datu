# %%
import os
import http.client
import json
import pandas as pd
from dotenv import load_dotenv
load_dotenv()

def rapidAPI_call(url):
    """
    Returns a dictionary of response data details depending on the rapidAPI url
    url = GET api enpoint
    Host = specific request rapidAPI url
    X_Key = assigned rapidAPI key for specific endpoing i.e. flights, flightDestination, hotels etc.
    X_host = usually the same as Host
    """
    secrets = json.loads(os.getenv("rapid_api_secrets"))
    X_key = secrets['X-Rapidapi-Key']
    X_host = secrets['X-Rapidapi-Host']
    Host = secrets['Host']
    conn = http.client.HTTPSConnection(f"{Host}")

    # Headers including the API key
    headers = {
        "X-Rapidapi-Key": f"{X_key}",
        "X-Rapidapi-Host": f"{X_host}"
    }

    conn.request("GET", f"{url}", headers=headers)
    response = conn.getresponse()
    data = response.read()
    dict = json.loads(data)
    #df = pd.DataFrame((dict['data']))
    return dict

#print(data.decode("utf-8"))
# Out:
# python-dotenv could not parse statement starting at line 2

# %%
secrets = json.loads(os.getenv("secrets"))
dest_url = secrets['flight_dest_url']

# %%
dict_dest = rapidAPI_call(dest_url)
dict_dest
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1749937926781,
#  'data': [{'id': 'NYC.CITY',
#    'type': 'CITY',
#    'name': 'New York',
#    'code': 'NYC',
#    'regionName': 'New York',
#    'country': 'US',
#    'countryName': 'United States',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/977436.jpg?k=ee0baaf82d482fae02bcb8dda25be1abff1da43d187bbb26ae6b2f3c9b5f4e61&o='},
#   {'id': 'JFK.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'John F. Kennedy International Airport',
#    'code': 'JFK',
#    'city': 'NYC',
#    'cityName': 'New York',
#    'regionName': 'New York',
#    'country': 'US',
#    'countryName': 'United States',
#    'countryNameShort': 'US',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/977436.jpg?k=ee0baaf82d482fae02bcb8dda25be1abff1da43d187bbb26ae6b2f3c9b5f4e61&o=',
#    'distanceToCity': {'value': 21.381514773782005, 'unit': 'km'},
#    'parent': 'NYC'},
#   {'id': 'EWR.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Newark Liberty International Airport',
#    'code': 'EWR',
#    'city': 'NYC',
#    'cityName': 'New York',
#    'region': 'NJ',
#    'regionName': 'New York',
#    'country': 'US',
#    'countryName': 'United States',
#    'countryNameShort': 'US',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/977436.jpg?k=ee0baaf82d482fae02bcb8dda25be1abff1da43d187bbb26ae6b2f3c9b5f4e61&o=',
#    'distanceToCity': {'value': 18.736453932482238, 'unit': 'km'},
#    'parent': 'NYC'},
#   {'id': 'LGA.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'LaGuardia Airport',
#    'code': 'LGA',
#    'city': 'NYC',
#    'cityName': 'New York',
#    'regionName': 'New York',
#    'country': 'US',
#    'countryName': 'United States',
#    'countryNameShort': 'US',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/977436.jpg?k=ee0baaf82d482fae02bcb8dda25be1abff1da43d187bbb26ae6b2f3c9b5f4e61&o=',
#    'distanceToCity': {'value': 9.28775750350465, 'unit': 'km'},
#    'parent': 'NYC'},
#   {'id': 'DEL.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Delhi International Airport',
#    'code': 'DEL',
#    'city': 'DEL',
#    'cityName': 'New Delhi',
#    'regionName': 'Delhi NCR',
#    'country': 'IN',
#    'countryName': 'India',
#    'countryNameShort': 'India',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/684764.jpg?k=6c3c9e920a39ca4f9eddcdfaa916999ea5d2765844610dd59349f4271f7596b3&o=',
#    'distanceToCity': {'value': 14.757868271664938, 'unit': 'km'},
#    'parent': 'DEL'},
#   {'id': 'SYD.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Sydney Kingsford Smith Airport',
#    'code': 'SYD',
#    'city': 'SYD',
#    'cityName': 'Sydney',
#    'regionName': 'New South Wales',
#    'country': 'AU',
#    'countryName': 'Australia',
#    'countryNameShort': 'Australia',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/977458.jpg?k=c44825bafc9d3cefc524dc982c691aa5b97e6218761f2b26b811212806f1f508&o=',
#    'distanceToCity': {'value': 7.8384264645051225, 'unit': 'km'},
#    'parent': 'SYD'},
#   {'id': 'AKL.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Auckland Airport',
#    'code': 'AKL',
#    'city': 'AKL',
#    'cityName': 'Auckland',
#    'regionName': 'Auckland Region',
#    'country': 'NZ',
#    'countryName': 'New Zealand',
#    'countryNameShort': 'New Zealand',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/682129.jpg?k=128ff3f77991fbcc27e08579272e3142b26c0565e4ea5c5e9f52ceb3001f74c9&o=',
#    'distanceToCity': {'value': 17.55107122110258, 'unit': 'km'},
#    'parent': 'AKL'},
#   {'id': 'SPK.CITY',
#    'type': 'CITY',
#    'name': 'Sapporo',
#    'code': 'SPK',
#    'regionName': 'Hokkaido',
#    'country': 'JP',
#    'countryName': 'Japan',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/644137.jpg?k=9a4bfb398d53bb499bb201a19f73832e3edb173e94c0a8df25755c796656ff2e&o='},
#   {'id': 'CTS.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'New Chitose Airport',
#    'code': 'CTS',
#    'city': 'SPK',
#    'cityName': 'Sapporo',
#    'regionName': 'Hokkaido',
#    'country': 'JP',
#    'countryName': 'Japan',
#    'countryNameShort': 'Japan',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/644137.jpg?k=9a4bfb398d53bb499bb201a19f73832e3edb173e94c0a8df25755c796656ff2e&o=',
#    'distanceToCity': {'value': 40.43772342755492, 'unit': 'km'},
#    'parent': 'SPK'},
#   {'id': 'BOS.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Logan Airport',
#    'code': 'BOS',
#    'city': 'BOS',
#    'cityName': 'Boston',
#    'regionName': 'Massachusetts',
#    'country': 'US',
#    'countryName': 'United States',
#    'countryNameShort': 'US',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/976694.jpg?k=2d9c7cfee16c559fd62fdc7cafb491f4b28494b99525fa00318186e6be96a202&o=',
#    'distanceToCity': {'value': 3.435917755292242, 'unit': 'km'},
#    'parent': 'BOS'},
#   {'id': 'NCL.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Newcastle International Airport',
#    'code': 'NCL',
#    'city': 'NCL',
#    'cityName': 'Newcastle upon Tyne',
#    'regionName': 'Tyne and Wear',
#    'country': 'GB',
#    'countryName': 'United Kingdom',
#    'countryNameShort': 'G.B.',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/687285.jpg?k=84f6f2377af1738b4ee29fccea1af65634fe4258712f96f54491c08f1d026a95&o=',
#    'distanceToCity': {'value': 9.304203979978428, 'unit': 'km'},
#    'parent': 'NCL'},
#   {'id': 'BUE.CITY',
#    'type': 'CITY',
#    'name': 'Buenos Aires',
#    'code': 'BUE',
#    'country': 'AR',
#    'countryName': 'Argentina',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/664049.jpg?k=fd691141ae6bdd6048ca0095f5d9bec810f571654be41c9bd556d645a474b025&o='},
#   {'id': 'AEP.AIRPORT',
#    'type': 'AIRPORT',
#    'name': 'Jorge Newbery Airfield',
#    'code': 'AEP',
#    'city': 'BUE',
#    'cityName': 'Buenos Aires',
#    'country': 'AR',
#    'countryName': 'Argentina',
#    'countryNameShort': 'Argentina',
#    'photoUri': 'https://q-xx.bstatic.com/xdata/images/city/square150/664049.jpg?k=fd691141ae6bdd6048ca0095f5d9bec810f571654be41c9bd556d645a474b025&o=',
#    'distanceToCity': {'value': 6.156122771135648, 'unit': 'km'},
#    'parent': 'BUE'}]}

# %%
BOM_AIRPORT = "JFK.AIRPORT"
DEL_AIRPORT = "CTS.AIRPORT"
depart_DATE = "2025-11-14"

flight_url = f"/api/v1/flights/searchFlights?fromId={BOM_AIRPORT}&toId={DEL_AIRPORT}&departDate={depart_DATE}"

# %%
df_flight = rapidAPI_call(flight_url)
df_flight
# Out:
# {'status': True,
#  'message': 'Success',
#  'timestamp': 1749938534945,
#  'data': {'aggregation': {'totalCount': 611,
#    'filteredTotalCount': 611,
#    'stops': [{'numberOfStops': 1,
#      'count': 170,
#      'minPrice': {'currencyCode': 'USD', 'units': 737, 'nanos': 200000000},
#      'minPriceRound': {'currencyCode': 'USD', 'units': 738, 'nanos': 0}},
#     {'numberOfStops': 2,
#      'count': 604,
#      'minPrice': {'currencyCode': 'USD', 'units': 737, 'nanos': 200000000},
#      'minPriceRound': {'currencyCode': 'USD', 'units': 738, 'nanos': 0}},
#     {'numberOfStops': 3,
#      'count': 611,
#      'minPrice': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000},
#      'minPriceRound': {'currencyCode': 'USD', 'units': 713, 'nanos': 0}}],
#    'airlines': [{'name': 'All Nippon Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/NH.png',
#      'iataCode': 'NH',
#      'count': 216,
#      'minPrice': {'currencyCode': 'USD', 'units': 853, 'nanos': 840000000}},
#     {'name': 'Japan Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png',
#      'iataCode': 'JL',
#      'count': 207,
#      'minPrice': {'currencyCode': 'USD', 'units': 737, 'nanos': 500000000}},
#     {'name': 'American Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/AA.png',
#      'iataCode': 'AA',
#      'count': 50,
#      'minPrice': {'currencyCode': 'USD', 'units': 818, 'nanos': 180000000}},
#     {'name': 'Cathay Pacific Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/CX.png',
#      'iataCode': 'CX',
#      'count': 27,
#      'minPrice': {'currencyCode': 'USD', 'units': 944, 'nanos': 960000000}},
#     {'name': 'Air Canada',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/AC.png',
#      'iataCode': 'AC',
#      'count': 25,
#      'minPrice': {'currencyCode': 'USD', 'units': 886, 'nanos': 700000000}},
#     {'name': 'China Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/CI.png',
#      'iataCode': 'CI',
#      'count': 25,
#      'minPrice': {'currencyCode': 'USD', 'units': 840, 'nanos': 400000000}},
#     {'name': 'Air Tahiti Nui',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/TN.png',
#      'iataCode': 'TN',
#      'count': 24,
#      'minPrice': {'currencyCode': 'USD', 'units': 1422, 'nanos': 140000000}},
#     {'name': 'Lufthansa',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/LH.png',
#      'iataCode': 'LH',
#      'count': 22,
#      'minPrice': {'currencyCode': 'USD', 'units': 2574, 'nanos': 390000000}},
#     {'name': 'Korean Air',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/KE.png',
#      'iataCode': 'KE',
#      'count': 17,
#      'minPrice': {'currencyCode': 'USD', 'units': 737, 'nanos': 200000000}},
#     {'name': 'Asiana Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/OZ.png',
#      'iataCode': 'OZ',
#      'count': 14,
#      'minPrice': {'currencyCode': 'USD', 'units': 737, 'nanos': 200000000}},
#     {'name': 'Qatar Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/QR.png',
#      'iataCode': 'QR',
#      'count': 11,
#      'minPrice': {'currencyCode': 'USD', 'units': 1112, 'nanos': 240000000}},
#     {'name': 'Singapore Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/SQ.png',
#      'iataCode': 'SQ',
#      'count': 10,
#      'minPrice': {'currencyCode': 'USD', 'units': 938, 'nanos': 600000000}},
#     {'name': 'China Eastern Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/MU.png',
#      'iataCode': 'MU',
#      'count': 10,
#      'minPrice': {'currencyCode': 'USD', 'units': 823, 'nanos': 950000000}},
#     {'name': 'Finnair',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/AY.png',
#      'iataCode': 'AY',
#      'count': 10,
#      'minPrice': {'currencyCode': 'USD', 'units': 1225, 'nanos': 390000000}},
#     {'name': 'Swiss',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/LX.png',
#      'iataCode': 'LX',
#      'count': 9,
#      'minPrice': {'currencyCode': 'USD', 'units': 2573, 'nanos': 530000000}},
#     {'name': 'Air China',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/CA.png',
#      'iataCode': 'CA',
#      'count': 8,
#      'minPrice': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000}},
#     {'name': 'Eva Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/BR.png',
#      'iataCode': 'BR',
#      'count': 6,
#      'minPrice': {'currencyCode': 'USD', 'units': 907, 'nanos': 480000000}},
#     {'name': 'Jetstar Japan',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/GK.png',
#      'iataCode': 'GK',
#      'count': 6,
#      'minPrice': {'currencyCode': 'USD', 'units': 980, 'nanos': 970000000}},
#     {'name': 'Air France',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/AF.png',
#      'iataCode': 'AF',
#      'count': 6,
#      'minPrice': {'currencyCode': 'USD', 'units': 1093, 'nanos': 340000000}},
#     {'name': 'Etihad Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/EY.png',
#      'iataCode': 'EY',
#      'count': 6,
#      'minPrice': {'currencyCode': 'USD', 'units': 2207, 'nanos': 0}},
#     {'name': 'United Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/UA.png',
#      'iataCode': 'UA',
#      'count': 5,
#      'minPrice': {'currencyCode': 'USD', 'units': 853, 'nanos': 700000000}},
#     {'name': 'KLM',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/KL.png',
#      'iataCode': 'KL',
#      'count': 4,
#      'minPrice': {'currencyCode': 'USD', 'units': 3359, 'nanos': 900000000}},
#     {'name': 'Sun Country',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/SY.png',
#      'iataCode': 'SY',
#      'count': 4,
#      'minPrice': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000}},
#     {'name': 'Philippine Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/PR.png',
#      'iataCode': 'PR',
#      'count': 3,
#      'minPrice': {'currencyCode': 'USD', 'units': 967, 'nanos': 120000000}},
#     {'name': 'Norse Atlantic Uk',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/Z0.png',
#      'iataCode': 'Z0',
#      'count': 3,
#      'minPrice': {'currencyCode': 'USD', 'units': 823, 'nanos': 950000000}},
#     {'name': 'Alaska Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/AS.png',
#      'iataCode': 'AS',
#      'count': 3,
#      'minPrice': {'currencyCode': 'USD', 'units': 1947, 'nanos': 200000000}},
#     {'name': 'Hawaiian Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/HA.png',
#      'iataCode': 'HA',
#      'count': 3,
#      'minPrice': {'currencyCode': 'USD', 'units': 7924, 'nanos': 200000000}},
#     {'name': 'Jin Air',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/LJ.png',
#      'iataCode': 'LJ',
#      'count': 3,
#      'minPrice': {'currencyCode': 'USD', 'units': 889, 'nanos': 840000000}},
#     {'name': 'Condor',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/DE.png',
#      'iataCode': 'DE',
#      'count': 2,
#      'minPrice': {'currencyCode': 'USD', 'units': 8236, 'nanos': 320000000}},
#     {'name': 'Juneyao Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/HO.png',
#      'iataCode': 'HO',
#      'count': 2,
#      'minPrice': {'currencyCode': 'USD', 'units': 7638, 'nanos': 460000000}},
#     {'name': 'Scoot',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/TR.png',
#      'iataCode': 'TR',
#      'count': 2,
#      'minPrice': {'currencyCode': 'USD', 'units': 968, 'nanos': 590000000}},
#     {'name': 'Malaysia Airlines',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/MH.png',
#      'iataCode': 'MH',
#      'count': 1,
#      'minPrice': {'currencyCode': 'USD', 'units': 1081, 'nanos': 530000000}},
#     {'name': 'Airasiax SDN BHD',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/D7.png',
#      'iataCode': 'D7',
#      'count': 1,
#      'minPrice': {'currencyCode': 'USD', 'units': 1081, 'nanos': 530000000}},
#     {'name': 'Thai Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/TG.png',
#      'iataCode': 'TG',
#      'count': 1,
#      'minPrice': {'currencyCode': 'USD', 'units': 883, 'nanos': 970000000}},
#     {'name': 'Cebu Air',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/5J.png',
#      'iataCode': '5J',
#      'count': 1,
#      'minPrice': {'currencyCode': 'USD', 'units': 967, 'nanos': 120000000}},
#     {'name': 'British Airways',
#      'logoUrl': 'https://r-xx.bstatic.com/data/airlines_logo/BA.png',
#      'iataCode': 'BA',
#      'count': 1,
#      'minPrice': {'currencyCode': 'USD', 'units': 6436, 'nanos': 700000000}}],
#    'departureIntervals': [{'start': '00:05', 'end': '22:45'}],
#    'flightTimes': [{'arrival': [{'start': '00:00', 'end': '05:59', 'count': 0},
#       {'start': '06:00', 'end': '11:59', 'count': 136},
#       {'start': '12:00', 'end': '17:59', 'count': 234},
#       {'start': '18:00', 'end': '23:59', 'count': 241}],
#      'departure': [{'start': '00:00', 'end': '05:59', 'count': 273},
#       {'start': '06:00', 'end': '11:59', 'count': 106},
#       {'start': '12:00', 'end': '17:59', 'count': 172},
#       {'start': '18:00', 'end': '23:59', 'count': 60}]}],
#    'shortLayoverConnection': {'count': 41},
#    'durationMin': 18,
#    'durationMax': 78,
#    'minPrice': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000},
#    'minRoundPrice': {'currencyCode': 'USD', 'units': 713, 'nanos': 0},
#    'minPriceFiltered': {'currencyCode': 'USD',
#     'units': 712,
#     'nanos': 170000000},
#    'baggage': [{'paramName': 'includedBaggage',
#      'count': 596,
#      'enabled': True,
#      'baggageType': 'CABIN'},
#     {'paramName': 'includedBaggage',
#      'count': 562,
#      'enabled': True,
#      'baggageType': 'CHECKIN'}],
#    'budget': {'paramName': 'maxBudget',
#     'min': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000},
#     'max': {'currencyCode': 'USD', 'units': 10563, 'nanos': 280000000}},
#    'budgetPerAdult': {'paramName': 'maxBudgetPerAdult',
#     'min': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000},
#     'max': {'currencyCode': 'USD', 'units': 10563, 'nanos': 280000000}},
#    'duration': [{'min': 18,
#      'max': 78,
#      'durationType': 'JOURNEY',
#      'enabled': True,
#      'paramName': 'maxDuration'},
#     {'min': 1,
#      'max': 48,
#      'durationType': 'LAYOVER',
#      'enabled': True,
#      'paramName': 'maxLayoverDuration'}],
#    'filtersOrder': ['stops', 'airlines', 'flightTimes', 'duration']},
#   'flightOffers': [{'token': 'd6a1f_H4sIAAAAAAAA_y2QbY-qMBCFf41-o7S8CJg0NwbRqwK6Cq7ulwZLwbp7t4Z2V3d__Z2I6WTOcyY57aRnY656bNvNh2zPRltfGrXKqLYyAnH1z246aCel3uVna1eys5ezVVzsiJev9zaxLTh8fPwjqqtEHWpociiSbT5JWbFdbNhmu4gX-Xwo7sbSHadDeRKoolYURT1qTsmTOjpC_hrPwmQTPkZcGeqh0SzYLOceyeb9sKPzculN-lRNs_h2W_9OdDbVoGWQF8cgfz-6ZXL9m-H7W3bR9xybMp0m7o686Kyo0318gxnk8GyVTjMvjcnbVt5M9jJwp1CPqwWH1RDygqh_SlX6uarihhLcY23o7rCPglVvDQ18jP2HuVPijpxoqMWH4Eaqz5X4ocvUt-Dv1LfjWzkD50QW8Z9-4MQEi8qpLkADdwLVMoww6PmpFUs99HoAOrGwBOEs3IPU7BSKhgMJZpGaVEAN86BLRlCfvbDFK8gvk23kqPA_nvsTBPoBAAA.',
#     'segments': [{'departureAirport': {'type': 'AIRPORT',
#        'code': 'JFK',
#        'name': 'John F. Kennedy International Airport',
#        'city': 'NYC',
#        'cityName': 'New York',
#        'country': 'US',
#        'countryName': 'United States',
#        'province': 'New York State',
#        'provinceCode': 'NY'},
#       'arrivalAirport': {'type': 'AIRPORT',
#        'code': 'CTS',
#        'name': 'New Chitose Airport',
#        'city': 'SPK',
#        'cityName': 'Sapporo',
#        'country': 'JP',
#        'countryName': 'Japan',
#        'province': 'Hokkaido'},
#       'departureTime': '2025-11-14T12:40:00',
#       'arrivalTime': '2025-11-15T21:15:00',
#       'legs': [{'departureTime': '2025-11-14T12:40:00',
#         'arrivalTime': '2025-11-15T17:15:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'JFK',
#          'name': 'John F. Kennedy International Airport',
#          'city': 'NYC',
#          'cityName': 'New York',
#          'country': 'US',
#          'countryName': 'United States',
#          'province': 'New York State',
#          'provinceCode': 'NY'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 5,
#          'planeType': '351',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 52500,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '8',
#         'arrivalTerminal': '3'},
#        {'departureTime': '2025-11-15T19:45:00',
#         'arrivalTime': '2025-11-15T21:15:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'CTS',
#          'name': 'New Chitose Airport',
#          'city': 'SPK',
#          'cityName': 'Sapporo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Hokkaido'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 529,
#          'planeType': '359',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 5400,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '1',
#         'arrivalTerminal': 'D'}],
#       'totalTime': 66900,
#       'travellerCheckedLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'CHECKED_IN',
#          'ruleType': 'PIECE_BASED',
#          'maxPiece': 2,
#          'maxWeightPerPiece': 50.7,
#          'massUnit': 'LB'}}],
#       'travellerCabinLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'HAND',
#          'maxPiece': 1,
#          'maxWeightPerPiece': 22.1,
#          'massUnit': 'LB',
#          'sizeRestrictions': {'maxLength': 21.7,
#           'maxWidth': 15.8,
#           'maxHeight': 9.8,
#           'sizeUnit': 'INCH'}},
#         'personalItem': True}],
#       'isAtolProtected': False,
#       'showWarningDestinationAirport': False,
#       'showWarningOriginAirport': False}],
#     'priceBreakdown': {'total': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#      'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#      'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#      'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#      'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#      'totalWithoutDiscount': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#       'nanos': 0,
#       'units': 751},
#      'carrierTaxBreakdown': [{'carrier': {'name': 'Japan Airlines',
#         'code': 'JL',
#         'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#        'avgPerAdult': {'currencyCode': 'USD',
#         'units': 206,
#         'nanos': 500000000}}],
#      'showPriceStrikethrough': False,
#      'carrierPriceBreakdown': []},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#        'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 751},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}],
#     'priceDisplayRequirements': ['AIR_PRICE_BREAKDOWN'],
#     'pointOfSale': 'us',
#     'tripType': 'ONEWAY',
#     'posMismatch': {'detectedPointOfSale': 'us',
#      'isPOSMismatch': False,
#      'offerSalesCountry': 'us'},
#     'includedProductsBySegment': [[{'travellerReference': '1',
#        'travellerProducts': [{'type': 'checkedInBaggage',
#          'product': {'luggageType': 'CHECKED_IN',
#           'ruleType': 'PIECE_BASED',
#           'maxPiece': 2,
#           'maxWeightPerPiece': 50.7,
#           'massUnit': 'LB'}},
#         {'type': 'cabinBaggage',
#          'product': {'luggageType': 'HAND',
#           'maxPiece': 1,
#           'maxWeightPerPiece': 22.1,
#           'massUnit': 'LB',
#           'sizeRestrictions': {'maxLength': 21.7,
#            'maxWidth': 15.8,
#            'maxHeight': 9.8,
#            'sizeUnit': 'INCH'}}},
#         {'type': 'personalItem'}]}]],
#     'includedProducts': {'areAllSegmentsIdentical': True,
#      'segments': [[{'luggageType': 'PERSONAL_ITEM',
#         'maxPiece': 1,
#         'piecePerPax': 1},
#        {'luggageType': 'HAND',
#         'maxPiece': 1,
#         'maxWeightPerPiece': 22.1,
#         'massUnit': 'LB',
#         'sizeRestrictions': {'maxLength': 21.7,
#          'maxWidth': 15.8,
#          'maxHeight': 9.8,
#          'sizeUnit': 'INCH'},
#         'piecePerPax': 1},
#        {'luggageType': 'CHECKED_IN',
#         'ruleType': 'PIECE_BASED',
#         'maxPiece': 2,
#         'maxWeightPerPiece': 50.7,
#         'massUnit': 'LB',
#         'piecePerPax': 2}]]},
#     'extraProducts': [{'type': 'flexibleTicket',
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'carrierPriceBreakdown': []}}],
#     'offerExtras': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 106},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 106},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'ancillaries': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'preSelected': False,
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'brandedFareInfo': {'fareName': 'Standard',
#      'features': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '2 checked bags (2 lbs total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}],
#      'fareAttributes': [],
#      'nonIncludedFeaturesRequired': False,
#      'nonIncludedFeatures': [],
#      'featuresList': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '2 checked bags (2 lbs total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}]},
#     'fareRules': [{'segmentIdentifiers': [{'segmentIndex': 0, 'legIndex': 0},
#        {'segmentIndex': 0, 'legIndex': 1}],
#       'availablePolicies': [],
#       'unavailablePolicies': [{'type': 'CANCEL_BEFORE'},
#        {'type': 'CHANGE_BEFORE'}]}],
#     'appliedDiscounts': [],
#     'offerKeyToHighlight': '1_JL5_JL529.JFK20251114',
#     'extraProductDisplayRequirements': {},
#     'unifiedPriceBreakdown': {'price': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'items': [{'scope': 'FLIGHT_ADULT',
#        'id': 'flight_adult',
#        'title': 'Adult (1)',
#        'price': {'currencyCode': 'USD', 'units': 750, 'nanos': 50000000},
#        'items': [{'id': 'flight_adult-basefare',
#          'title': 'Flight fare',
#          'price': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#          'items': []},
#         {'id': 'flight_adult-tax',
#          'title': 'Taxes and airline fees',
#          'price': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#          'items': []}]},
#       {'scope': 'DISCOUNT',
#        'id': 'flight_adult-fee',
#        'title': 'Third-party discount',
#        'price': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'items': []}],
#      'addedItems': []}},
#    {'token': 'd6a1f_H4sIAAAAAAAA_y2QYW-qMBSGf41-o7QCQk2aG4PoVECn4J370mAp2G13NbSbbr_-nojpyXmf9yRve9KztRczcd3mQ7Vna5wvg1ptdVtZiYT-5zYdtJPW7-qzdSvVuav5Oi72xM83B5e4DhwxOf6R1UWhDjUseSmSXT5NebFbbvl2t4yX-WIob9YxnWBDdZKoYg6ltEcjGHlQx8Yo2OB5lGyj-0hoy3w0nofb1cIn2VM_7NiiXPnTPlWzLL5eN79Tk80MaBnmxTHM349emVyeMnx7zd7MLce2TGeJtyfPJivq9BBfYQY5PF-ns8xPY_K6U1ebPQ-8GdT9ailgNYT8kPZP6co8VtXCMoJ7rC3bvxxouO6tZWGAcXA3N0a88YgOjfyQwir9uZY_bJUGDvyd_h4FTs7BUeqQ4OEHo5hg5V1-KqCBN4VqOUYY9PzQiqc-Oo6BTjwqQQSPDiA1P0WyEUCSO6QmFVDDfeiKE9Rn3_jyL8gvVy0d6eg_L2NdT_oBAAA.',
#     'segments': [{'departureAirport': {'type': 'AIRPORT',
#        'code': 'JFK',
#        'name': 'John F. Kennedy International Airport',
#        'city': 'NYC',
#        'cityName': 'New York',
#        'country': 'US',
#        'countryName': 'United States',
#        'province': 'New York State',
#        'provinceCode': 'NY'},
#       'arrivalAirport': {'type': 'AIRPORT',
#        'code': 'CTS',
#        'name': 'New Chitose Airport',
#        'city': 'SPK',
#        'cityName': 'Sapporo',
#        'country': 'JP',
#        'countryName': 'Japan',
#        'province': 'Hokkaido'},
#       'departureTime': '2025-11-14T12:40:00',
#       'arrivalTime': '2025-11-15T22:05:00',
#       'legs': [{'departureTime': '2025-11-14T12:40:00',
#         'arrivalTime': '2025-11-15T17:15:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'JFK',
#          'name': 'John F. Kennedy International Airport',
#          'city': 'NYC',
#          'cityName': 'New York',
#          'country': 'US',
#          'countryName': 'United States',
#          'province': 'New York State',
#          'provinceCode': 'NY'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 5,
#          'planeType': '351',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 52500,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '8',
#         'arrivalTerminal': '3'},
#        {'departureTime': '2025-11-15T20:30:00',
#         'arrivalTime': '2025-11-15T22:05:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'CTS',
#          'name': 'New Chitose Airport',
#          'city': 'SPK',
#          'cityName': 'Sapporo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Hokkaido'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 599,
#          'planeType': '73H',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 5700,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '1',
#         'arrivalTerminal': 'D'}],
#       'totalTime': 69900,
#       'travellerCheckedLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'CHECKED_IN',
#          'ruleType': 'PIECE_BASED',
#          'maxPiece': 2,
#          'maxWeightPerPiece': 50.7,
#          'massUnit': 'LB'}}],
#       'travellerCabinLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'HAND',
#          'maxPiece': 1,
#          'maxWeightPerPiece': 22.1,
#          'massUnit': 'LB',
#          'sizeRestrictions': {'maxLength': 21.7,
#           'maxWidth': 15.8,
#           'maxHeight': 9.8,
#           'sizeUnit': 'INCH'}},
#         'personalItem': True}],
#       'isAtolProtected': False,
#       'showWarningDestinationAirport': False,
#       'showWarningOriginAirport': False}],
#     'priceBreakdown': {'total': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#      'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#      'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#      'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#      'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#      'totalWithoutDiscount': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#       'nanos': 0,
#       'units': 751},
#      'carrierTaxBreakdown': [{'carrier': {'name': 'Japan Airlines',
#         'code': 'JL',
#         'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#        'avgPerAdult': {'currencyCode': 'USD',
#         'units': 206,
#         'nanos': 500000000}}],
#      'showPriceStrikethrough': False,
#      'carrierPriceBreakdown': []},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#        'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 751},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}],
#     'priceDisplayRequirements': ['AIR_PRICE_BREAKDOWN'],
#     'pointOfSale': 'us',
#     'tripType': 'ONEWAY',
#     'posMismatch': {'detectedPointOfSale': 'us',
#      'isPOSMismatch': False,
#      'offerSalesCountry': 'us'},
#     'includedProductsBySegment': [[{'travellerReference': '1',
#        'travellerProducts': [{'type': 'checkedInBaggage',
#          'product': {'luggageType': 'CHECKED_IN',
#           'ruleType': 'PIECE_BASED',
#           'maxPiece': 2,
#           'maxWeightPerPiece': 50.7,
#           'massUnit': 'LB'}},
#         {'type': 'cabinBaggage',
#          'product': {'luggageType': 'HAND',
#           'maxPiece': 1,
#           'maxWeightPerPiece': 22.1,
#           'massUnit': 'LB',
#           'sizeRestrictions': {'maxLength': 21.7,
#            'maxWidth': 15.8,
#            'maxHeight': 9.8,
#            'sizeUnit': 'INCH'}}},
#         {'type': 'personalItem'}]}]],
#     'includedProducts': {'areAllSegmentsIdentical': True,
#      'segments': [[{'luggageType': 'PERSONAL_ITEM',
#         'maxPiece': 1,
#         'piecePerPax': 1},
#        {'luggageType': 'HAND',
#         'maxPiece': 1,
#         'maxWeightPerPiece': 22.1,
#         'massUnit': 'LB',
#         'sizeRestrictions': {'maxLength': 21.7,
#          'maxWidth': 15.8,
#          'maxHeight': 9.8,
#          'sizeUnit': 'INCH'},
#         'piecePerPax': 1},
#        {'luggageType': 'CHECKED_IN',
#         'ruleType': 'PIECE_BASED',
#         'maxPiece': 2,
#         'maxWeightPerPiece': 50.7,
#         'massUnit': 'LB',
#         'piecePerPax': 2}]]},
#     'extraProducts': [{'type': 'flexibleTicket',
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'carrierPriceBreakdown': []}}],
#     'offerExtras': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 106},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 106},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'ancillaries': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'preSelected': False,
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'brandedFareInfo': {'fareName': 'Standard',
#      'features': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '2 checked bags (2 lbs total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}],
#      'fareAttributes': [],
#      'nonIncludedFeaturesRequired': False,
#      'nonIncludedFeatures': [],
#      'featuresList': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '2 checked bags (2 lbs total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}]},
#     'fareRules': [{'segmentIdentifiers': [{'segmentIndex': 0, 'legIndex': 0},
#        {'segmentIndex': 0, 'legIndex': 1}],
#       'availablePolicies': [],
#       'unavailablePolicies': [{'type': 'CANCEL_BEFORE'},
#        {'type': 'CHANGE_BEFORE'}]}],
#     'appliedDiscounts': [],
#     'offerKeyToHighlight': '1_JL5_JL599.JFK20251114',
#     'extraProductDisplayRequirements': {},
#     'unifiedPriceBreakdown': {'price': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'items': [{'scope': 'FLIGHT_ADULT',
#        'id': 'flight_adult',
#        'title': 'Adult (1)',
#        'price': {'currencyCode': 'USD', 'units': 750, 'nanos': 50000000},
#        'items': [{'id': 'flight_adult-basefare',
#          'title': 'Flight fare',
#          'price': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#          'items': []},
#         {'id': 'flight_adult-tax',
#          'title': 'Taxes and airline fees',
#          'price': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#          'items': []}]},
#       {'scope': 'DISCOUNT',
#        'id': 'flight_adult-fee',
#        'title': 'Third-party discount',
#        'price': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'items': []}],
#      'addedItems': []}},
#    {'token': 'd6a1f_H4sIAAAAAAAA_y2QbW-CMBSFf41-o7QCAkuaxSA6FNApuLkvDZaC3Ys1tJtuv343Ynpzz3NuctqbHo056wfbbj5lezTa-taoVUa1lRGIqy-76aAdlPqQp9auZGcvZsuo2BI3X-1sYltw-MP-UVRniTrU0Pi1iDf5JGXFJlmz9SaJknw-FFdj6Y7ToTwIVFErDMMeNafkTh0dI2-FZ0G8Dm4jrgx10Xjmrxdzl2RJP-zovFy4kz5V0yy6XFZ_E51NNWjp58Xezz_2ThmfnzJ8fcve9TXHpkynsbMlzzor6nQXXWAGOTxbptPMTSPytpEXkz0PnCnU7WrBYTWEXD_sn1KVvq-quKEE91gbun3dhf6yt4b6HsbezVwpccajcKjFp-BGqtNS_NJF6lnwd-pn5Fk5A-cQi3h3PxhFBFfdacyBBs4EqmUYYdDjXSuWumg_BzqwoAThLNiB1OwQiIYDCWaRmlRADXOhS0ZQn31nyQvIH5NtOFLBP2Oo8oX6AQAA',
#     'segments': [{'departureAirport': {'type': 'AIRPORT',
#        'code': 'JFK',
#        'name': 'John F. Kennedy International Airport',
#        'city': 'NYC',
#        'cityName': 'New York',
#        'country': 'US',
#        'countryName': 'United States',
#        'province': 'New York State',
#        'provinceCode': 'NY'},
#       'arrivalAirport': {'type': 'AIRPORT',
#        'code': 'CTS',
#        'name': 'New Chitose Airport',
#        'city': 'SPK',
#        'cityName': 'Sapporo',
#        'country': 'JP',
#        'countryName': 'Japan',
#        'province': 'Hokkaido'},
#       'departureTime': '2025-11-14T12:40:00',
#       'arrivalTime': '2025-11-15T22:15:00',
#       'legs': [{'departureTime': '2025-11-14T12:40:00',
#         'arrivalTime': '2025-11-15T17:15:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'JFK',
#          'name': 'John F. Kennedy International Airport',
#          'city': 'NYC',
#          'cityName': 'New York',
#          'country': 'US',
#          'countryName': 'United States',
#          'province': 'New York State',
#          'provinceCode': 'NY'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 5,
#          'planeType': '351',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 52500,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '8',
#         'arrivalTerminal': '3'},
#        {'departureTime': '2025-11-15T20:40:00',
#         'arrivalTime': '2025-11-15T22:15:00',
#         'departureAirport': {'type': 'AIRPORT',
#          'code': 'HND',
#          'name': 'Tokyo Haneda Airport',
#          'city': 'TYO',
#          'cityName': 'Tokyo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Tokyo To'},
#         'arrivalAirport': {'type': 'AIRPORT',
#          'code': 'CTS',
#          'name': 'New Chitose Airport',
#          'city': 'SPK',
#          'cityName': 'Sapporo',
#          'country': 'JP',
#          'countryName': 'Japan',
#          'province': 'Hokkaido'},
#         'cabinClass': 'ECONOMY',
#         'flightInfo': {'facilities': [],
#          'flightNumber': 531,
#          'planeType': '359',
#          'carrierInfo': {'operatingCarrier': 'JL',
#           'marketingCarrier': 'JL',
#           'operatingCarrierDisclosureText': ''}},
#         'carriers': ['JL', 'JL'],
#         'carriersData': [{'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#          {'name': 'Japan Airlines',
#           'code': 'JL',
#           'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'}],
#         'totalTime': 5700,
#         'flightStops': [],
#         'amenities': [],
#         'departureTerminal': '1',
#         'arrivalTerminal': 'D'}],
#       'totalTime': 70500,
#       'travellerCheckedLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'CHECKED_IN',
#          'ruleType': 'PIECE_BASED',
#          'maxPiece': 2,
#          'maxWeightPerPiece': 50.7,
#          'massUnit': 'LB'}}],
#       'travellerCabinLuggage': [{'travellerReference': '1',
#         'luggageAllowance': {'luggageType': 'HAND',
#          'maxPiece': 1,
#          'maxWeightPerPiece': 22.1,
#          'massUnit': 'LB',
#          'sizeRestrictions': {'maxLength': 21.7,
#           'maxWidth': 15.8,
#           'maxHeight': 9.8,
#           'sizeUnit': 'INCH'}},
#         'personalItem': True}],
#       'isAtolProtected': False,
#       'showWarningDestinationAirport': False,
#       'showWarningOriginAirport': False}],
#     'priceBreakdown': {'total': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#      'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#      'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#      'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#      'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#      'totalWithoutDiscount': {'currencyCode': 'USD',
#       'units': 750,
#       'nanos': 50000000},
#      'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#       'nanos': 0,
#       'units': 751},
#      'carrierTaxBreakdown': [{'carrier': {'name': 'Japan Airlines',
#         'code': 'JL',
#         'logo': 'https://r-xx.bstatic.com/data/airlines_logo/JL.png'},
#        'avgPerAdult': {'currencyCode': 'USD',
#         'units': 206,
#         'nanos': 500000000}}],
#      'showPriceStrikethrough': False,
#      'carrierPriceBreakdown': []},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#        'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 751},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}],
#     'priceDisplayRequirements': ['AIR_PRICE_BREAKDOWN'],
#     'pointOfSale': 'us',
#     'tripType': 'ONEWAY',
#     'posMismatch': {'detectedPointOfSale': 'us',
#      'isPOSMismatch': False,
#      'offerSalesCountry': 'us'},
#     'includedProductsBySegment': [[{'travellerReference': '1',
#        'travellerProducts': [{'type': 'checkedInBaggage',
#          'product': {'luggageType': 'CHECKED_IN',
#           'ruleType': 'PIECE_BASED',
#           'maxPiece': 2,
#           'maxWeightPerPiece': 50.7,
#           'massUnit': 'LB'}},
#         {'type': 'cabinBaggage',
#          'product': {'luggageType': 'HAND',
#           'maxPiece': 1,
#           'maxWeightPerPiece': 22.1,
#           'massUnit': 'LB',
#           'sizeRestrictions': {'maxLength': 21.7,
#            'maxWidth': 15.8,
#            'maxHeight': 9.8,
#            'sizeUnit': 'INCH'}}},
#         {'type': 'personalItem'}]}]],
#     'includedProducts': {'areAllSegmentsIdentical': True,
#      'segments': [[{'luggageType': 'PERSONAL_ITEM',
#         'maxPiece': 1,
#         'piecePerPax': 1},
#        {'luggageType': 'HAND',
#         'maxPiece': 1,
#         'maxWeightPerPiece': 22.1,
#         'massUnit': 'LB',
#         'sizeRestrictions': {'maxLength': 21.7,
#          'maxWidth': 15.8,
#          'maxHeight': 9.8,
#          'sizeUnit': 'INCH'},
#         'piecePerPax': 1},
#        {'luggageType': 'CHECKED_IN',
#         'ruleType': 'PIECE_BASED',
#         'maxPiece': 2,
#         'maxWeightPerPiece': 50.7,
#         'massUnit': 'LB',
#         'piecePerPax': 2}]]},
#     'extraProducts': [{'type': 'flexibleTicket',
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'carrierPriceBreakdown': []}}],
#     'offerExtras': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 106},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 106},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'ancillaries': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 105, 'nanos': 10000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 105,
#         'nanos': 10000000},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'preSelected': False,
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'brandedFareInfo': {'fareName': 'Standard',
#      'features': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
# ...
#           'maxPiece': 1,
#           'maxWeightPerPiece': 22.1,
#           'massUnit': 'LB',
#           'sizeRestrictions': {'maxLength': 21.7,
#            'maxWidth': 15.8,
#            'maxHeight': 9.8,
#            'sizeUnit': 'INCH'}}},
#         {'type': 'personalItem'}]}]],
#     'includedProducts': {'areAllSegmentsIdentical': True,
#      'segments': [[{'luggageType': 'PERSONAL_ITEM',
#         'maxPiece': 1,
#         'piecePerPax': 1},
#        {'luggageType': 'HAND',
#         'maxPiece': 1,
#         'maxWeightPerPiece': 22.1,
#         'massUnit': 'LB',
#         'sizeRestrictions': {'maxLength': 21.7,
#          'maxWidth': 15.8,
#          'maxHeight': 9.8,
#          'sizeUnit': 'INCH'},
#         'piecePerPax': 1},
#        {'luggageType': 'CHECKED_IN',
#         'ruleType': 'PIECE_BASED',
#         'maxPiece': 1,
#         'maxWeightPerPiece': 50.7,
#         'massUnit': 'LB',
#         'piecePerPax': 1}]]},
#     'extraProducts': [{'type': 'flexibleTicket',
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 119, 'nanos': 780000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'carrierPriceBreakdown': []}}],
#     'offerExtras': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 119, 'nanos': 780000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 120},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 120},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'ancillaries': {'flexibleTicket': {'airProductReference': 'n/a',
#       'travellers': ['1'],
#       'priceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 119, 'nanos': 780000000},
#        'fee': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'tax': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 119,
#         'nanos': 780000000},
#        'showPriceStrikethrough': False,
#        'carrierPriceBreakdown': []},
#       'preSelected': False,
#       'recommendation': {'recommended': False, 'confidence': 'UNKNOWN_LEVEL'},
#       'supplierInfo': {'name': 'Gotogate, Inc.',
#        'termsUrl': 'https://flights-us.gotogate.com/rf/travel-conditions',
#        'privacyPolicyUrl': 'https://flights-us.gotogate.com/rf/privacy-policy'}}},
#     'brandedFareInfo': {'fareName': 'ECO I BASIC 1N',
#      'cabinClass': 'ECONOMY',
#      'features': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '1 checked bag (1 lb total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}],
#      'fareAttributes': [],
#      'nonIncludedFeaturesRequired': False,
#      'nonIncludedFeatures': [],
#      'featuresList': [{'featureName': 'PERSONAL_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK03',
#        'label': '1 personal items',
#        'availability': 'INCLUDED',
#        'icon': 'PERSONAL_LUGGAGE_ICON'},
#       {'featureName': 'CABIN_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK02',
#        'label': '1 carry-on bag (1 lb)\t',
#        'availability': 'INCLUDED',
#        'icon': 'CABIN_LUGGAGE_ICON'},
#       {'featureName': 'CHECK_BAGGAGE',
#        'category': 'BAGGAGE',
#        'code': 'BK01',
#        'label': '1 checked bag (1 lb total)',
#        'availability': 'INCLUDED',
#        'icon': 'CHECKED_IN_LUGGAGE_ICON'}]},
#     'fareRules': [{'segmentIdentifiers': [{'segmentIndex': 0, 'legIndex': 0},
#        {'segmentIndex': 0, 'legIndex': 1}],
#       'availablePolicies': [],
#       'unavailablePolicies': [{'type': 'CANCEL_BEFORE'},
#        {'type': 'CHANGE_BEFORE'}]}],
#     'appliedDiscounts': [],
#     'offerKeyToHighlight': '1_NH109_NH79.JFK20251114',
#     'requestableBrandedFares': True,
#     'extraProductDisplayRequirements': {},
#     'unifiedPriceBreakdown': {'price': {'currencyCode': 'USD',
#       'units': 855,
#       'nanos': 580000000},
#      'items': [{'scope': 'FLIGHT_ADULT',
#        'id': 'flight_adult',
#        'title': 'Adult (1)',
#        'price': {'currencyCode': 'USD', 'units': 855, 'nanos': 580000000},
#        'items': [{'id': 'flight_adult-basefare',
#          'title': 'Flight fare',
#          'price': {'currencyCode': 'USD', 'units': 673, 'nanos': 0},
#          'items': []},
#         {'id': 'flight_adult-tax',
#          'title': 'Taxes and airline fees',
#          'price': {'currencyCode': 'USD', 'units': 186, 'nanos': 300000000},
#          'items': []}]},
#       {'scope': 'DISCOUNT',
#        'id': 'flight_adult-fee',
#        'title': 'Third-party discount',
#        'price': {'currencyCode': 'USD', 'units': -3, 'nanos': -720000000},
#        'items': []}],
#      'addedItems': []}}],
#   'flightDeals': [{'key': 'CHEAPEST',
#     'offerToken': 'd6a1f_H4sIAAAAAAAA_02Q226jMBBAvyZ5w2AgXCpZK8qthGuBpSUvFjGE0HZLhN0lm69fL0SryuOZc0Yj2_KZsQt9EMXTx9CfGRW-KOhHNvYN6wAZf4mniafjOL4Pn73YDJO490K7LKCapJUIRYEv8lD_6JrLACZwQu5r6eaJFeEyDzKc5YEdJP62uzKBTgRth2MHGiSYprkiJQi6oX-XCWlgl0qe4WbG0iIjQyrQPD3b-6psKmtzQv5T5RykxVoU2_McORaNHbrWYr6mN-85ct_1-I1QvvWo2heRU0vp7eAn8DHMb0mSOrEel48vCZ-PvRpGjquUjqXH1TmKnDxPhpnFzxvF4bFc1RH-WgBU3YSLjw1FuiGvTBiC93bLUPFamXq4KkM6lKG-yBVBRZPNLe0-OsKG8TPs_qCi3mmGwL90_C3vhBoXtSrDb25bpqH-94g71EwBanffyHZP5vEycNgoFo8eS2BZnM_fuMF7A2QBOEjAeeJ-xMZPXgg2XnhpsWmQ1uDUYbiDUOZ0wirPA4b3E95w8G_0htvui7bKXx1njgY-AgAA',
#     'price': {'currencyCode': 'USD', 'units': 712, 'nanos': 170000000},
#     'priceRounded': {'currencyCode': 'USD', 'units': 713, 'nanos': 0},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 712,
#         'nanos': 170000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 472, 'nanos': 380000000},
#        'fee': {'currencyCode': 'USD', 'units': 86, 'nanos': 290000000},
#        'tax': {'currencyCode': 'USD', 'units': 153, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 713},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 712,
#         'nanos': 170000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 713},
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}]},
#    {'key': 'FASTEST',
#     'offerToken': 'd6a1f_H4sIAAAAAAAA_zWQ3W6jMBCFnya5w9gxv5WsFQKSDQGSJpA2vbHAGELTrSPsNmyffr0lla053xzp2GOflbrKB9Ns3_rurKTxIUEnlOgqxQETf8x20KUW4tK_d2bVD2ay3ITFAVn59mgi09CLPZx-8eragwG0JH4u4n0epLTYr3d0t1-H63w156My5MDIvK85qIjh-_6EkhF0p4E4wN7CpRfvvG-LCUUs4CzdXbKy0ONiMgeyKhMrmFINycLbbfsVyCySWks3L05ufjnhMr7-zuD4kr3KMYeqTKMYH9CjzIomPYY37ekczHAaZVYawjGLLjIt4hmOvg_mTA8GgOX600WikvdBBVMEwQkbRQ7PR9_dTK0invPzspEg7Cz8ueRvnKlevG_4X5Kk2NA_Jz4XtnGgSWpDZCD73s8WIYK1LT5GTTMc6N1RCKDW810r-gKCUkNNvf_CqHfU0tDGwTXTxKmBGtvR1FJL154iMEVf6fpJyxdth6bq8T_8OUHf9wEAAA..',
#     'price': {'currencyCode': 'USD', 'units': 869, 'nanos': 990000000},
#     'priceRounded': {'currencyCode': 'USD', 'units': 870, 'nanos': 0},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 869,
#         'nanos': 990000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 671, 'nanos': 0},
#        'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -510000000},
#        'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 870},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 869,
#         'nanos': 990000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 870},
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}]},
#    {'key': 'BEST',
#     'offerToken': 'd6a1f_H4sIAAAAAAAA_y2QbY-qMBCFf41-o7S8CJg0NwbRqwK6Cq7ulwZLwbp7t4Z2V3d__Z2I6WTOcyY57aRnY656bNvNh2zPRltfGrXKqLYyAnH1z246aCel3uVna1eys5ezVVzsiJev9zaxLTh8fPwjqqtEHWpociiSbT5JWbFdbNhmu4gX-Xwo7sbSHadDeRKoolYURT1qTsmTOjpC_hrPwmQTPkZcGeqh0SzYLOceyeb9sKPzculN-lRNs_h2W_9OdDbVoGWQF8cgfz-6ZXL9m-H7W3bR9xybMp0m7o686Kyo0318gxnk8GyVTjMvjcnbVt5M9jJwp1CPqwWH1RDygqh_SlX6uarihhLcY23o7rCPglVvDQ18jP2HuVPijpxoqMWH4Eaqz5X4ocvUt-Dv1LfjWzkD50QW8Z9-4MQEi8qpLkADdwLVMoww6PmpFUs99HoAOrGwBOEs3IPU7BSKhgMJZpGaVEAN86BLRlCfvbDFK8gvk23kqPA_nvsTBPoBAAA.',
#     'price': {'currencyCode': 'USD', 'units': 750, 'nanos': 50000000},
#     'priceRounded': {'currencyCode': 'USD', 'units': 751, 'nanos': 0},
#     'travellerPrices': [{'travellerPriceBreakdown': {'total': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'baseFare': {'currencyCode': 'USD', 'units': 551, 'nanos': 0},
#        'fee': {'currencyCode': 'USD', 'units': -7, 'nanos': -450000000},
#        'tax': {'currencyCode': 'USD', 'units': 206, 'nanos': 500000000},
#        'totalRounded': {'currencyCode': 'USD', 'nanos': 0, 'units': 751},
#        'discount': {'currencyCode': 'USD', 'units': 0, 'nanos': 0},
#        'totalWithoutDiscount': {'currencyCode': 'USD',
#         'units': 750,
#         'nanos': 50000000},
#        'totalWithoutDiscountRounded': {'currencyCode': 'USD',
#         'nanos': 0,
#         'units': 751},
#        'carrierPriceBreakdown': []},
#       'travellerReference': '1',
#       'travellerType': 'ADULT'}]}],
#   'atolProtectedStatus': 'NONE',
#   'searchId': 'B1644E80463E1EB935CAEA9762B59109',
#   'banners': [],
#   'displayOptions': {'brandedFaresShownByDefault': False,
#    'directFlightsOnlyFilterIgnored': False,
#    'hideFlexiblePricesBanner': False},
#   'isOffersCabinClassExtended': False,
#   'cabinClassExtension': {},
#   'searchCriteria': {'cabinClass': 'ECONOMY'},
#   'baggagePolicies': [{'code': 'NH',
#     'name': 'All Nippon Airways',
#     'url': 'http://www.ana.co.jp/en/eur/international/prepare/baggage'},
#    {'code': 'JL',
#     'name': 'Japan Airlines',
#     'url': 'https://www.jal.co.jp/jp/en/inter/baggage/checked/'},
#    {'code': 'AA',
#     'name': 'American Airlines',
#     'url': 'https://aa.com/i18n/travel-info/baggage/checked-baggage-policy.jsp'},
#    {'code': 'CX',
#     'name': 'Cathay Pacific Airways',
#     'url': 'https://www.cathaypacific.com/cx/en_HK/travel-information/baggage.html'},
#    {'code': 'AC',
#     'name': 'Air Canada',
#     'url': 'https://www.aircanada.com/uk/en/aco/home/plan/baggage/checked.html'},
#    {'code': 'CI',
#     'name': 'China Airlines',
#     'url': 'https://www.china-airlines.com/us/en/fly/prepare-for-the-fly/baggage/baggage-rules'},
#    {'code': 'TN',
#     'name': 'Air Tahiti Nui',
#     'url': 'https://www.airtahitinui.com/us-en/baggage-policies'},
#    {'code': 'LH',
#     'name': 'Lufthansa',
#     'url': 'https://www.lufthansa.com/se/en/Carry-on-baggage'},
#    {'code': 'KE',
#     'name': 'Korean Air',
#     'url': 'https://www.koreanair.com/gr/en/airport/baggage/overview'},
#    {'code': 'OZ',
#     'name': 'Asiana Airlines',
#     'url': 'https://flyasiana.com/C/US/EN/contents/user-guide'},
#    {'code': 'QR',
#     'name': 'Qatar Airways',
#     'url': 'https://www.qatarairways.com/en-se/baggage.html'},
#    {'code': 'SQ',
#     'name': 'Singapore Airlines',
#     'url': 'http://www.singaporeair.com/en_UK/sg/travel-info/baggage/checked-baggage'},
#    {'code': 'MU',
#     'name': 'China Eastern Airlines',
#     'url': 'http://www.ceair.com/guide2/tyxl/index.html'},
#    {'code': 'AY',
#     'name': 'Finnair',
#     'url': 'https://www.finnair.com/gb/gb/information-services/baggage'},
#    {'code': 'LX',
#     'name': 'Swiss',
#     'url': 'https://www.swiss.com/se/EN/prepare/baggage'},
#    {'code': 'CA',
#     'name': 'Air China',
#     'url': 'https://webresource.airchina.com.cn/zh-CN/content/travel_info/preparing/luggage/limit/'},
#    {'code': 'BR',
#     'name': 'Eva Airways',
#     'url': 'https://www.evaair.com/en-us/fly-prepare/baggage/'},
#    {'code': 'GK',
#     'name': 'Jetstar Japan',
#     'url': 'https://www.jetstar.com/jp/en/flights/baggage'},
#    {'code': 'AF',
#     'name': 'Air France',
#     'url': 'https://wwws.airfrance.nl/information/bagages/bagage-cabine-soute'},
#    {'code': 'EY',
#     'name': 'Etihad Airways',
#     'url': 'http://www.etihad.com/en-se/before-you-fly/baggage-information'},
#    {'code': 'UA',
#     'name': 'United Airlines',
#     'url': 'https://www.united.com/web/en-US/content/travel/baggage/default.aspx'},
#    {'code': 'KL',
#     'name': 'KLM',
#     'url': 'https://www.klm.se/en/information/baggage'},
#    {'code': 'SY',
#     'name': 'Sun Country',
#     'url': 'https://suncountry.com/bags-optional-services'},
#    {'code': 'PR',
#     'name': 'Philippine Airlines',
#     'url': 'https://www.philippineairlines.com/en/travelinformation/beforeyoufly/baggageinformation'},
#    {'code': 'Z0',
#     'name': 'Norse Atlantic Uk',
#     'url': 'https://flynorse.com/support/baggage'},
#    {'code': 'AS',
#     'name': 'Alaska Airlines',
#     'url': 'https://www.alaskaair.com/content/travel-info/baggage/overview'},
#    {'code': 'HA',
#     'name': 'Hawaiian Airlines',
#     'url': 'https://hawaiianair.custhelp.com/'},
#    {'code': 'LJ',
#     'name': 'Jin Air',
#     'url': 'https://images.jinair.com/eForm/%EA%B5%AD%EC%A0%9C%EC%97%AC%EA%B0%9D%EC%9A%B4%EC%86%A1%EC%95%BD%EA%B4%80_ENG.pdf?20211129'},
#    {'code': 'DE',
#     'name': 'Condor',
#     'url': 'https://www.condor.com/eu/flight-preparation/baggage-and-animals/baggage.jsp'},
#    {'code': 'HO',
#     'name': 'Juneyao Airlines',
#     'url': 'https://global.juneyaoair.com/servicehelp/new/Baggage'},
#    {'code': 'TR',
#     'name': 'Scoot',
#     'url': 'https://www.flyscoot.com/en/plan/booking-your-flight/baggage'},
#    {'code': 'MH',
#     'name': 'Malaysia Airlines',
#     'url': 'https://www.malaysiaairlines.com/us/en/plan-your-trip.html'},
#    {'code': 'D7',
#     'name': 'Airasiax SDN BHD',
#     'url': 'https://www.airasia.com/aa/inflight-comforts/en/gb/baggage.html'},
#    {'code': 'TG',
#     'name': 'Thai Airways',
#     'url': 'https://www.thaiairways.com/en_TH/plan/travel_information/baggage.page?'},
#    {'code': '5J',
#     'name': 'Cebu Air',
#     'url': 'https://www.cebupacificair.com/pages/travel-info/baggage-information/carry-on-baggage'},
#    {'code': 'BA',
#     'name': 'British Airways',
#     'url': 'https://www.britishairways.com/en-gb/information/baggage-essentials'}],
#   'personalisationSegments': ['FRUGAL_COMPANIONS',
#    'LONG_HAUL_TRIP',
#    'FAMILY_TRAVELLERS'],
#   'priceAlertStatus': {'isEligible': False,
#    'isSearchEligible': True,
#    'isBlockoutEligible': True}}}

# %%
df=pd.DataFrame(df_flight)

# %%
df
# Out:
#                             status  message      timestamp  \
# aggregation                   True  Success  1749938534945
# flightOffers                  True  Success  1749938534945
# flightDeals                   True  Success  1749938534945
# atolProtectedStatus           True  Success  1749938534945
# searchId                      True  Success  1749938534945
# banners                       True  Success  1749938534945
# displayOptions                True  Success  1749938534945
# isOffersCabinClassExtended    True  Success  1749938534945
# cabinClassExtension           True  Success  1749938534945
# searchCriteria                True  Success  1749938534945
# baggagePolicies               True  Success  1749938534945
# personalisationSegments       True  Success  1749938534945
# priceAlertStatus              True  Success  1749938534945
#
#                                                                          data
# aggregation                 {'totalCount': 611, 'filteredTotalCount': 611,...
# flightOffers                [{'token': 'd6a1f_H4sIAAAAAAAA_y2QbY-qMBCFf41-...
# flightDeals                 [{'key': 'CHEAPEST', 'offerToken': 'd6a1f_H4sI...
# atolProtectedStatus                                                      NONE
# searchId                                     B1644E80463E1EB935CAEA9762B59109
# banners                                                                    []
# displayOptions              {'brandedFaresShownByDefault': False, 'directF...
# isOffersCabinClassExtended                                              False
# cabinClassExtension                                                        {}
# searchCriteria                                      {'cabinClass': 'ECONOMY'}
# baggagePolicies             [{'code': 'NH', 'name': 'All Nippon Airways', ...
# personalisationSegments     [FRUGAL_COMPANIONS, LONG_HAUL_TRIP, FAMILY_TRA...
# priceAlertStatus            {'isEligible': False, 'isSearchEligible': True...

# %%
df.query('status == "flightOffers"', engine='python')
# Out:
# Empty DataFrame
# Columns: [status, message, timestamp, data]
# Index: []

# %%
df1 = pd.DataFrame(df.iloc[1]['data'])

# %%
df1
# Out:
#                                                 token  \
# 0   d6a1f_H4sIAAAAAAAA_y2QbY-qMBCFf41-o7S8CJg0NwbR...
# 1   d6a1f_H4sIAAAAAAAA_y2QYW-qMBSGf41-o7QCQk2aG4Po...
# 2   d6a1f_H4sIAAAAAAAA_y2QbW-CMBSFf41-o7QCAkuaxSA6...
# 3   d6a1f_H4sIAAAAAAAA_y2Q23KCMBRFv0bfCIRbwJlMx1q0...
# 4   d7699_H4sIAAAAAAAA_y2Qba-CIBiGf019EyXf29iZM_NU...
# 5   d6a1f_H4sIAAAAAAAA_y2QbW-CMBSFf41-o1ABgSXN4qAq...
# 6   d6a1f_H4sIAAAAAAAA_y2QW4-CMBCFf42-UaiAgEmzMYCK...
# 7   d6a1f_H4sIAAAAAAAA_y2QbW-CMBSFf41-o1ChAibN4gAV...
# 8   d6a1f_H4sIAAAAAAAA_zWQ3W6jMBCFnya5w9gxv5WsFQKS...
# 9   d6a1f_H4sIAAAAAAAA_y2Q3XKCMBBGn0bvCESBgDOZjkW0...
# 10  d6a1f_H4sIAAAAAAAA_y1QXXOiMBT9NfpGIIAEOpPZsRhd...
# 11  d7699_H4sIAAAAAAAA_y2Q246CMBRFv0bfKFTuJs2EIDIq...
# 12  d7699_H4sIAAAAAAAA_y2Qa5OCIBSGf019EyUVtRlmxylz...
# 13  d7699_H4sIAAAAAAAA_y2Q2Y6CMBSGn0bvKJRFikkzIYqM...
# 14  d6a1f_H4sIAAAAAAAA_y2QbW-CMBSFf41-o1ChAibNYgAV...
#
#                                              segments  \
# 0   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 1   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 2   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 3   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 4   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 5   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 6   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 7   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 8   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 9   [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 10  [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 11  [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 12  [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 13  [{'departureAirport': {'type': 'AIRPORT', 'cod...
# 14  [{'departureAirport': {'type': 'AIRPORT', 'cod...
#
#                                        priceBreakdown  \
# 0   {'total': {'currencyCode': 'USD', 'units': 750...
# 1   {'total': {'currencyCode': 'USD', 'units': 750...
# 2   {'total': {'currencyCode': 'USD', 'units': 750...
# 3   {'total': {'currencyCode': 'USD', 'units': 817...
# 4   {'total': {'currencyCode': 'USD', 'units': 818...
# 5   {'total': {'currencyCode': 'USD', 'units': 855...
# 6   {'total': {'currencyCode': 'USD', 'units': 855...
# 7   {'total': {'currencyCode': 'USD', 'units': 855...
# 8   {'total': {'currencyCode': 'USD', 'units': 869...
# 9   {'total': {'currencyCode': 'USD', 'units': 817...
# 10  {'total': {'currencyCode': 'USD', 'units': 737...
# 11  {'total': {'currencyCode': 'USD', 'units': 818...
# 12  {'total': {'currencyCode': 'USD', 'units': 818...
# 13  {'total': {'currencyCode': 'USD', 'units': 838...
# 14  {'total': {'currencyCode': 'USD', 'units': 855...
#
#                                       travellerPrices  \
# 0   [{'travellerPriceBreakdown': {'total': {'curre...
# 1   [{'travellerPriceBreakdown': {'total': {'curre...
# 2   [{'travellerPriceBreakdown': {'total': {'curre...
# 3   [{'travellerPriceBreakdown': {'total': {'curre...
# 4   [{'travellerPriceBreakdown': {'total': {'curre...
# 5   [{'travellerPriceBreakdown': {'total': {'curre...
# 6   [{'travellerPriceBreakdown': {'total': {'curre...
# 7   [{'travellerPriceBreakdown': {'total': {'curre...
# 8   [{'travellerPriceBreakdown': {'total': {'curre...
# 9   [{'travellerPriceBreakdown': {'total': {'curre...
# 10  [{'travellerPriceBreakdown': {'total': {'curre...
# 11  [{'travellerPriceBreakdown': {'total': {'curre...
# 12  [{'travellerPriceBreakdown': {'total': {'curre...
# 13  [{'travellerPriceBreakdown': {'total': {'curre...
# 14  [{'travellerPriceBreakdown': {'total': {'curre...
#
#    priceDisplayRequirements pointOfSale tripType  \
# 0     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 1     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 2     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 3     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 4     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 5                        []          us   ONEWAY
# 6                        []          us   ONEWAY
# 7                        []          us   ONEWAY
# 8     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 9     [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 10                       []          us   ONEWAY
# 11    [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 12    [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 13    [AIR_PRICE_BREAKDOWN]          us   ONEWAY
# 14                       []          us   ONEWAY
#
#                                           posMismatch  \
# 0   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 1   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 2   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 3   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 4   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 5   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 6   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 7   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 8   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 9   {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 10  {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 11  {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 12  {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 13  {'detectedPointOfSale': 'us', 'isPOSMismatch':...
# 14  {'detectedPointOfSale': 'us', 'isPOSMismatch':...
#
#                             includedProductsBySegment  \
# 0   [[{'travellerReference': '1', 'travellerProduc...
# 1   [[{'travellerReference': '1', 'travellerProduc...
# 2   [[{'travellerReference': '1', 'travellerProduc...
# 3   [[{'travellerReference': '1', 'travellerProduc...
# 4   [[{'travellerReference': '1', 'travellerProduc...
# 5   [[{'travellerReference': '1', 'travellerProduc...
# 6   [[{'travellerReference': '1', 'travellerProduc...
# 7   [[{'travellerReference': '1', 'travellerProduc...
# 8   [[{'travellerReference': '1', 'travellerProduc...
# 9   [[{'travellerReference': '1', 'travellerProduc...
# 10  [[{'travellerReference': '1', 'travellerProduc...
# 11  [[{'travellerReference': '1', 'travellerProduc...
# 12  [[{'travellerReference': '1', 'travellerProduc...
# 13  [[{'travellerReference': '1', 'travellerProduc...
# 14  [[{'travellerReference': '1', 'travellerProduc...
#
#                                      includedProducts  ...  \
# 0   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 1   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 2   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 3   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 4   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 5   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 6   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 7   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 8   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 9   {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 10  {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 11  {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 12  {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 13  {'areAllSegmentsIdentical': True, 'segments': ...  ...
# 14  {'areAllSegmentsIdentical': True, 'segments': ...  ...
#
#                                           offerExtras  \
# 0   {'flexibleTicket': {'airProductReference': 'n/...
# 1   {'flexibleTicket': {'airProductReference': 'n/...
# 2   {'flexibleTicket': {'airProductReference': 'n/...
# 3   {'flexibleTicket': {'airProductReference': 'n/...
# 4   {'flexibleTicket': {'airProductReference': 'n/...
# 5   {'flexibleTicket': {'airProductReference': 'n/...
# 6   {'flexibleTicket': {'airProductReference': 'n/...
# 7   {'flexibleTicket': {'airProductReference': 'n/...
# 8   {'flexibleTicket': {'airProductReference': 'n/...
# 9   {'flexibleTicket': {'airProductReference': 'n/...
# 10  {'flexibleTicket': {'airProductReference': 'n/...
# 11  {'flexibleTicket': {'airProductReference': 'n/...
# 12  {'flexibleTicket': {'airProductReference': 'n/...
# 13  {'flexibleTicket': {'airProductReference': 'n/...
# 14  {'flexibleTicket': {'airProductReference': 'n/...
#
#                                           ancillaries  \
# 0   {'flexibleTicket': {'airProductReference': 'n/...
# 1   {'flexibleTicket': {'airProductReference': 'n/...
# 2   {'flexibleTicket': {'airProductReference': 'n/...
# 3   {'flexibleTicket': {'airProductReference': 'n/...
# 4   {'flexibleTicket': {'airProductReference': 'n/...
# 5   {'flexibleTicket': {'airProductReference': 'n/...
# 6   {'flexibleTicket': {'airProductReference': 'n/...
# 7   {'flexibleTicket': {'airProductReference': 'n/...
# 8   {'flexibleTicket': {'airProductReference': 'n/...
# 9   {'flexibleTicket': {'airProductReference': 'n/...
# 10  {'flexibleTicket': {'airProductReference': 'n/...
# 11  {'flexibleTicket': {'airProductReference': 'n/...
# 12  {'flexibleTicket': {'airProductReference': 'n/...
# 13  {'flexibleTicket': {'airProductReference': 'n/...
# 14  {'flexibleTicket': {'airProductReference': 'n/...
#
#                                       brandedFareInfo  \
# 0   {'fareName': 'Standard', 'features': [{'featur...
# 1   {'fareName': 'Standard', 'features': [{'featur...
# 2   {'fareName': 'Standard', 'features': [{'featur...
# 3   {'fareName': 'Standard', 'features': [{'featur...
# 4   {'fareName': 'MAIN CABIN', 'cabinClass': 'ECON...
# 5   {'fareName': 'ECO I BASIC 1N', 'cabinClass': '...
# 6   {'fareName': 'ECO I BASIC 1N', 'cabinClass': '...
# 7   {'fareName': 'ECO I BASIC 1N', 'cabinClass': '...
# 8   {'fareName': 'Standard', 'features': [{'featur...
# 9   {'fareName': 'Standard', 'features': [{'featur...
# 10  {'fareName': 'ECONOMY SAVER', 'cabinClass': 'E...
# 11  {'fareName': 'MAIN CABIN', 'cabinClass': 'ECON...
# 12  {'fareName': 'MAIN CABIN', 'cabinClass': 'ECON...
# 13  {'fareName': 'MAIN CABIN', 'cabinClass': 'ECON...
# 14  {'fareName': 'ECO I BASIC 1N', 'cabinClass': '...
#
#                                             fareRules appliedDiscounts  \
# 0   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 1   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 2   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 3   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 4   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 5   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 6   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 7   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 8   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 9   [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 10  [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 11  [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 12  [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 13  [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
# 14  [{'segmentIdentifiers': [{'segmentIndex': 0, '...               []
#
#            offerKeyToHighlight extraProductDisplayRequirements  \
# 0      1_JL5_JL529.JFK20251114                              {}
# 1      1_JL5_JL599.JFK20251114                              {}
# 2      1_JL5_JL531.JFK20251114                              {}
# 3   1_JL7009_JL523.JFK20251114                              {}
# 4    1_AA167_JL523.JFK20251114                              {}
# 5   1_NH159_NH4711.JFK20251114                              {}
# 6     1_NH109_NH77.JFK20251114                              {}
# 7     1_NH159_NH51.JFK20251114                              {}
# 8      1_JL3_JL501.JFK20251114                              {}
# 9   1_JL7009_JL525.JFK20251114                              {}
# 10    1_KE86_KE765.JFK20251114                              {}
# 11   1_AA167_JL525.JFK20251114                              {}
# 12  1_AA167_AA8406.JFK20251114                              {}
# 13  1_AA8402_JL529.JFK20251114                              {}
# 14    1_NH109_NH79.JFK20251114                              {}
#
#                                 unifiedPriceBreakdown  \
# 0   {'price': {'currencyCode': 'USD', 'units': 750...
# 1   {'price': {'currencyCode': 'USD', 'units': 750...
# 2   {'price': {'currencyCode': 'USD', 'units': 750...
# 3   {'price': {'currencyCode': 'USD', 'units': 817...
# 4   {'price': {'currencyCode': 'USD', 'units': 818...
# 5   {'price': {'currencyCode': 'USD', 'units': 855...
# 6   {'price': {'currencyCode': 'USD', 'units': 855...
# 7   {'price': {'currencyCode': 'USD', 'units': 855...
# 8   {'price': {'currencyCode': 'USD', 'units': 869...
# 9   {'price': {'currencyCode': 'USD', 'units': 817...
# 10  {'price': {'currencyCode': 'USD', 'units': 737...
# 11  {'price': {'currencyCode': 'USD', 'units': 818...
# 12  {'price': {'currencyCode': 'USD', 'units': 818...
# 13  {'price': {'currencyCode': 'USD', 'units': 838...
# 14  {'price': {'currencyCode': 'USD', 'units': 855...
#
#                  seatAvailability requestableBrandedFares
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3   {'numberOfSeatsAvailable': 4}                     NaN
# 4   {'numberOfSeatsAvailable': 4}                    True
# 5                             NaN                    True
# 6                             NaN                    True
# 7                             NaN                    True
# 8                             NaN                     NaN
# 9   {'numberOfSeatsAvailable': 4}                     NaN
# 10                            NaN                    True
# 11                            NaN                    True
# 12                            NaN                    True
# 13                            NaN                    True
# 14                            NaN                    True
#
# [15 rows x 21 columns]
